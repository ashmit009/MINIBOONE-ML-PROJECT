# %% [markdown]
# <a href="https://colab.research.google.com/github/ashmit009/ML-PROJECTS/blob/main/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **To implement Gradient descent and Ascent on the function f(x)=2xy+y^2+6x+2y
# Learning Rate = 0.1 and inital point is (2,-2)**

# %%
import numpy as np
import sympy as sm
# Define the function f(x,y)
def f(x, y):
    return 2*x*y + y**2 + 6*x + 2*y

# Define the gradients of the function
def gradients(x, y):
    grad_x = 2*y + 6
    grad_y = 2*x + 2*y + 2
    return np.array([grad_x, grad_y])

# Gradient Descent Algorithm
def gradient_descent(initial_point, learning_rate, iterations):
    point = np.array(initial_point)
    for i in range(iterations):
        grad = gradients(point[0], point[1])
        point = point - learning_rate * grad
    return point

# %%
initial_point = (2, -2)
learning_rate = 0.1
iterations = 10


minimum_point = gradient_descent(initial_point, learning_rate, iterations)
minimum_point
# Out:
# array([ 0.57460275, -2.09901169])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function f(x,y)
def f(x, y):
    return 2*x*y + y**2 + 6*x + 2*y

def gradients(x, y):
    grad_x = 2*y + 6
    grad_y = 2*x + 2*y + 2
    return np.array([grad_x, grad_y])

def gradient_descent(initial_point, learning_rate, iterations):
    point = np.array(initial_point)
    path = [point]
    for i in range(iterations):
        grad = gradients(point[0], point[1])
        point = point - learning_rate * grad
        path.append(point)
    return np.array(path)

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
Z = f(X, Y)
initial_point = (2, -2)
learning_rate = 0.1
iterations = 10
path = gradient_descent(initial_point, learning_rate, iterations)
plt.plot(path[:,0], path[:,1], marker='o', color='black')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gradient Descent Plot')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x,y):
  return 2*x*y + y**2 + 6*x + 2*y

def gradients(x, y):
    grad_x = 2*y + 6
    grad_y = 2*x + 2*y + 2
    return np.array([grad_x, grad_y])

# %%
def gradient_descent(initial_point, learning_rate, iterations):
    point = np.array(initial_point)
    path = [point]
    for i in range(iterations):
        grad = gradients(point[0], point[1])
        point = point + learning_rate * grad
        path.append(point)
    return np.array(path)

    x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
Z = f(X, Y)
initial_point = (2, -2)
learning_rate = 0.1
iterations = 10
path = gradient_descent(initial_point, learning_rate, iterations)
plt.plot(path[:,0], path[:,1], marker='o', color='black')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gradient Ascent Plot')
plt.show()
